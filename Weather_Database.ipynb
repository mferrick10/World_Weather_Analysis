# %%
# Dependencies
import pandas as pd
import requests
import time

# %%
from citipy import citipy
# Imports the weather API key from my config file
from config import weather_api_key
from datetime import datetime
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Creates random coordinates
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 630

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]['description']
        city_rainfall = []
        try:
            city_rainfall = city_weather['rain']['3h']
        except:
            city_rainfall = 0
            pass
        city_snowfall = []
        try:
            city_snowfall = city_weather['snow']['3h']
        except:
            city_snowfall = 0
            pass
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description,
                          "Rain Inches (last 3 hrs)": city_rainfall,
                          "Snow Inches (last 3 hrs)": city_snowfall,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ponta do sol
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 1 | hirara
# Processing Record 6 of Set 1 | jacareacanga
# Processing Record 7 of Set 1 | pyshchug
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | hongjiang
# Processing Record 10 of Set 1 | maamba
# Processing Record 11 of Set 1 | alugan
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | coihaique
# Processing Record 14 of Set 1 | dalianwan
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | kahului
# Processing Record 18 of Set 1 | sangar
# Processing Record 19 of Set 1 | sola
# Processing Record 20 of Set 1 | altamira
# Processing Record 21 of Set 1 | borogontsy
# Processing Record 22 of Set 1 | riyadh
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | sao filipe
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | mindelo
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | balkanabat
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | vedaranniyam
# City not found. Skipping...
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | kavieng
# Processing Record 36 of Set 1 | naica
# Processing Record 37 of Set 1 | arraial do cabo
# Processing Record 38 of Set 1 | van buren
# Processing Record 39 of Set 1 | morant bay
# Processing Record 40 of Set 1 | culipapa
# City not found. Skipping...
# Processing Record 41 of Set 1 | kaeo
# Processing Record 42 of Set 1 | miandrivazo
# Processing Record 43 of Set 1 | isiro
# Processing Record 44 of Set 1 | ust-tsilma
# Processing Record 45 of Set 1 | lompoc
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | barranca
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | ottawa
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 2 | puerto baquerizo moreno
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | taltal
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 2 | shenavan
# Processing Record 8 of Set 2 | flinders
# Processing Record 9 of Set 2 | andselv
# City not found. Skipping...
# Processing Record 10 of Set 2 | tuatapere
# Processing Record 11 of Set 2 | bengkulu
# Processing Record 12 of Set 2 | bethel
# Processing Record 13 of Set 2 | cap-aux-meules
# Processing Record 14 of Set 2 | tubuala
# Processing Record 15 of Set 2 | srednekolymsk
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | manggar
# Processing Record 18 of Set 2 | vila velha
# Processing Record 19 of Set 2 | catamarca
# Processing Record 20 of Set 2 | funadhoo
# Processing Record 21 of Set 2 | slyudyanka
# Processing Record 22 of Set 2 | pandan
# Processing Record 23 of Set 2 | santona
# Processing Record 24 of Set 2 | acoyapa
# Processing Record 25 of Set 2 | iqaluit
# Processing Record 26 of Set 2 | lipari
# Processing Record 27 of Set 2 | torbay
# Processing Record 28 of Set 2 | newport
# Processing Record 29 of Set 2 | jalingo
# Processing Record 30 of Set 2 | aberdeen
# Processing Record 31 of Set 2 | kieta
# Processing Record 32 of Set 2 | teguldet
# Processing Record 33 of Set 2 | mahebourg
# Processing Record 34 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 2 | abashiri
# Processing Record 36 of Set 2 | puerto ayora
# Processing Record 37 of Set 2 | laiwu
# Processing Record 38 of Set 2 | mogadishu
# Processing Record 39 of Set 2 | cape town
# Processing Record 40 of Set 2 | jiangyou
# Processing Record 41 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 2 | praia da vitoria
# Processing Record 43 of Set 2 | norman wells
# Processing Record 44 of Set 2 | esperance
# Processing Record 45 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 2 | mar del plata
# Processing Record 47 of Set 2 | aksu
# Processing Record 48 of Set 2 | meulaboh
# Processing Record 49 of Set 2 | manokwari
# Processing Record 50 of Set 2 | shache
# Processing Record 1 of Set 3 | barcelos
# Processing Record 2 of Set 3 | qarchi gak
# Processing Record 3 of Set 3 | fare
# Processing Record 4 of Set 3 | jamestown
# Processing Record 5 of Set 3 | monte alegre
# Processing Record 6 of Set 3 | sapulpa
# Processing Record 7 of Set 3 | nata
# Processing Record 8 of Set 3 | tasiilaq
# Processing Record 9 of Set 3 | natal
# Processing Record 10 of Set 3 | buin
# Processing Record 11 of Set 3 | cabalantian
# City not found. Skipping...
# Processing Record 12 of Set 3 | san patricio
# Processing Record 13 of Set 3 | mugur-aksy
# Processing Record 14 of Set 3 | qaanaaq
# Processing Record 15 of Set 3 | takaka
# Processing Record 16 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 3 | te anau
# Processing Record 18 of Set 3 | vaini
# Processing Record 19 of Set 3 | yashkul
# Processing Record 20 of Set 3 | chuy
# Processing Record 21 of Set 3 | carnarvon
# Processing Record 22 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 3 | severo-kurilsk
# Processing Record 24 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 3 | ribeira grande
# Processing Record 26 of Set 3 | matsanga
# City not found. Skipping...
# Processing Record 27 of Set 3 | bluff
# Processing Record 28 of Set 3 | zaltan
# Processing Record 29 of Set 3 | sharon
# Processing Record 30 of Set 3 | takoradi
# Processing Record 31 of Set 3 | azul
# Processing Record 32 of Set 3 | abu jubayhah
# City not found. Skipping...
# Processing Record 33 of Set 3 | sao joao da barra
# Processing Record 34 of Set 3 | yulara
# Processing Record 35 of Set 3 | ferme-neuve
# Processing Record 36 of Set 3 | armacao dos buzios
# City not found. Skipping...
# Processing Record 37 of Set 3 | naryan-mar
# Processing Record 38 of Set 3 | victoria
# Processing Record 39 of Set 3 | bredasdorp
# Processing Record 40 of Set 3 | yarada
# Processing Record 41 of Set 3 | kodiak
# Processing Record 42 of Set 3 | sibolga
# Processing Record 43 of Set 3 | hobart
# Processing Record 44 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 3 | kenai
# Processing Record 46 of Set 3 | upernavik
# Processing Record 47 of Set 3 | albany
# Processing Record 48 of Set 3 | seydi
# Processing Record 49 of Set 3 | aklavik
# Processing Record 50 of Set 3 | souillac
# Processing Record 1 of Set 4 | chokurdakh
# Processing Record 2 of Set 4 | upata
# Processing Record 3 of Set 4 | humaita
# Processing Record 4 of Set 4 | tuktoyaktuk
# Processing Record 5 of Set 4 | benito juarez
# Processing Record 6 of Set 4 | provideniya
# Processing Record 7 of Set 4 | poienile de sub munte
# Processing Record 8 of Set 4 | akot
# Processing Record 9 of Set 4 | kununurra
# Processing Record 10 of Set 4 | zemio
# Processing Record 11 of Set 4 | cheney
# Processing Record 12 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 13 of Set 4 | panzhihua
# Processing Record 14 of Set 4 | sundvollen
# City not found. Skipping...
# Processing Record 15 of Set 4 | irun
# Processing Record 16 of Set 4 | lebu
# Processing Record 17 of Set 4 | el espinal
# Processing Record 18 of Set 4 | ahlat
# Processing Record 19 of Set 4 | nizhnyaya tavda
# Processing Record 20 of Set 4 | kokstad
# Processing Record 21 of Set 4 | port-gentil
# Processing Record 22 of Set 4 | tougue
# Processing Record 23 of Set 4 | barrow
# Processing Record 24 of Set 4 | bathsheba
# Processing Record 25 of Set 4 | nikolskoye
# Processing Record 26 of Set 4 | half moon bay
# Processing Record 27 of Set 4 | conceicao do araguaia
# Processing Record 28 of Set 4 | butaritari
# Processing Record 29 of Set 4 | honiara
# Processing Record 30 of Set 4 | broken hill
# Processing Record 31 of Set 4 | obregon
# Processing Record 32 of Set 4 | kholmogory
# Processing Record 33 of Set 4 | luena
# Processing Record 34 of Set 4 | leningradskiy
# Processing Record 35 of Set 4 | college
# Processing Record 36 of Set 4 | insar
# Processing Record 37 of Set 4 | cherskiy
# Processing Record 38 of Set 4 | nanortalik
# Processing Record 39 of Set 4 | dunedin
# Processing Record 40 of Set 4 | hasaki
# Processing Record 41 of Set 4 | lavrentiya
# Processing Record 42 of Set 4 | georgetown
# Processing Record 43 of Set 4 | castro
# Processing Record 44 of Set 4 | vostok
# Processing Record 45 of Set 4 | saskylakh
# Processing Record 46 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 4 | comodoro rivadavia
# Processing Record 48 of Set 4 | touros
# Processing Record 49 of Set 4 | port alfred
# Processing Record 50 of Set 4 | merauke
# Processing Record 1 of Set 5 | hornepayne
# Processing Record 2 of Set 5 | namibe
# Processing Record 3 of Set 5 | ambon
# Processing Record 4 of Set 5 | anadyr
# Processing Record 5 of Set 5 | cacoal
# Processing Record 6 of Set 5 | khatanga
# Processing Record 7 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 5 | havelock
# Processing Record 9 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 5 | acarau
# Processing Record 11 of Set 5 | clarence town
# Processing Record 12 of Set 5 | tila
# Processing Record 13 of Set 5 | afua
# Processing Record 14 of Set 5 | kaitangata
# Processing Record 15 of Set 5 | narsaq
# Processing Record 16 of Set 5 | soyo
# Processing Record 17 of Set 5 | pevek
# Processing Record 18 of Set 5 | pyu
# Processing Record 19 of Set 5 | cockburn town
# Processing Record 20 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 21 of Set 5 | ahipara
# Processing Record 22 of Set 5 | bafq
# Processing Record 23 of Set 5 | waitati
# Processing Record 24 of Set 5 | songjianghe
# Processing Record 25 of Set 5 | havoysund
# Processing Record 26 of Set 5 | bilibino
# Processing Record 27 of Set 5 | kuvandyk
# Processing Record 28 of Set 5 | chapais
# Processing Record 29 of Set 5 | imperatriz
# Processing Record 30 of Set 5 | trinidad
# Processing Record 31 of Set 5 | sitka
# Processing Record 32 of Set 5 | lagoa
# Processing Record 33 of Set 5 | kalabo
# Processing Record 34 of Set 5 | baniachang
# Processing Record 35 of Set 5 | lorengau
# Processing Record 36 of Set 5 | coquimbo
# Processing Record 37 of Set 5 | fort nelson
# Processing Record 38 of Set 5 | waslala
# Processing Record 39 of Set 5 | saint george
# Processing Record 40 of Set 5 | santa isabel do rio negro
# Processing Record 41 of Set 5 | tarbagatay
# Processing Record 42 of Set 5 | tankhoy
# Processing Record 43 of Set 5 | mayo
# Processing Record 44 of Set 5 | behbahan
# Processing Record 45 of Set 5 | gobo
# Processing Record 46 of Set 5 | turukhansk
# Processing Record 47 of Set 5 | hondo
# Processing Record 48 of Set 5 | kerteh
# City not found. Skipping...
# Processing Record 49 of Set 5 | solnechnyy
# Processing Record 50 of Set 5 | tiksi
# Processing Record 1 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 6 | asau
# Processing Record 4 of Set 6 | saldanha
# Processing Record 5 of Set 6 | nazca
# Processing Record 6 of Set 6 | ponta delgada
# Processing Record 7 of Set 6 | ulladulla
# Processing Record 8 of Set 6 | batagay-alyta
# Processing Record 9 of Set 6 | luderitz
# Processing Record 10 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 11 of Set 6 | carnot
# Processing Record 12 of Set 6 | inta
# Processing Record 13 of Set 6 | cozumel
# Processing Record 14 of Set 6 | sokolo
# Processing Record 15 of Set 6 | north marysville
# City not found. Skipping...
# Processing Record 16 of Set 6 | vila
# Processing Record 17 of Set 6 | san quintin
# Processing Record 18 of Set 6 | tabou
# Processing Record 19 of Set 6 | cap malheureux
# Processing Record 20 of Set 6 | tessalit
# Processing Record 21 of Set 6 | poum
# Processing Record 22 of Set 6 | huarmey
# Processing Record 23 of Set 6 | walvis bay
# Processing Record 24 of Set 6 | ndele
# Processing Record 25 of Set 6 | sept-iles
# Processing Record 26 of Set 6 | laramie
# Processing Record 27 of Set 6 | matinhos
# Processing Record 28 of Set 6 | creteni
# Processing Record 29 of Set 6 | grindavik
# Processing Record 30 of Set 6 | laiyang
# Processing Record 31 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 6 | khandyga
# Processing Record 33 of Set 6 | beloha
# Processing Record 34 of Set 6 | makokou
# Processing Record 35 of Set 6 | medea
# Processing Record 36 of Set 6 | talnakh
# Processing Record 37 of Set 6 | araouane
# Processing Record 38 of Set 6 | cabo san lucas
# Processing Record 39 of Set 6 | komsomolskiy
# Processing Record 40 of Set 6 | lower hutt
# Processing Record 41 of Set 6 | oneonta
# Processing Record 42 of Set 6 | inza
# Processing Record 43 of Set 6 | plettenberg bay
# Processing Record 44 of Set 6 | richards bay
# Processing Record 45 of Set 6 | piacabucu
# Processing Record 46 of Set 6 | kondinskoye
# Processing Record 47 of Set 6 | huangchuan
# Processing Record 48 of Set 6 | susanville
# Processing Record 49 of Set 6 | senador jose porfirio
# Processing Record 50 of Set 6 | tabulbah
# City not found. Skipping...
# Processing Record 1 of Set 7 | ancud
# Processing Record 2 of Set 7 | lethem
# Processing Record 3 of Set 7 | russell
# Processing Record 4 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 5 of Set 7 | clyde river
# Processing Record 6 of Set 7 | longyearbyen
# Processing Record 7 of Set 7 | qaqortoq
# Processing Record 8 of Set 7 | kjollefjord
# Processing Record 9 of Set 7 | varkaus
# Processing Record 10 of Set 7 | nhulunbuy
# Processing Record 11 of Set 7 | inverness
# Processing Record 12 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 7 | iskateley
# Processing Record 14 of Set 7 | sao gabriel da cachoeira
# Processing Record 15 of Set 7 | saraland
# Processing Record 16 of Set 7 | looc
# Processing Record 17 of Set 7 | ekhabi
# Processing Record 18 of Set 7 | hamilton
# Processing Record 19 of Set 7 | prince rupert
# Processing Record 20 of Set 7 | saint pete beach
# Processing Record 21 of Set 7 | filimonovo
# Processing Record 22 of Set 7 | bluefield
# Processing Record 23 of Set 7 | makat
# Processing Record 24 of Set 7 | saint-augustin
# Processing Record 25 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 7 | kabelvag
# Processing Record 27 of Set 7 | mount isa
# Processing Record 28 of Set 7 | el dorado
# Processing Record 29 of Set 7 | kruisfontein
# Processing Record 30 of Set 7 | wladyslawowo
# Processing Record 31 of Set 7 | santa maria
# Processing Record 32 of Set 7 | kangaatsiaq
# Processing Record 33 of Set 7 | husavik
# Processing Record 34 of Set 7 | port augusta
# Processing Record 35 of Set 7 | palmer
# Processing Record 36 of Set 7 | alofi
# Processing Record 37 of Set 7 | pulandian
# Processing Record 38 of Set 7 | alice
# Processing Record 39 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 40 of Set 7 | sioux lookout
# Processing Record 41 of Set 7 | calvinia
# Processing Record 42 of Set 7 | chiredzi
# Processing Record 43 of Set 7 | constitucion
# Processing Record 44 of Set 7 | jequie
# Processing Record 45 of Set 7 | yola
# Processing Record 46 of Set 7 | mehamn
# Processing Record 47 of Set 7 | bundaberg
# Processing Record 48 of Set 7 | macau
# Processing Record 49 of Set 7 | ilulissat
# Processing Record 50 of Set 7 | marzuq
# Processing Record 1 of Set 8 | paamiut
# Processing Record 2 of Set 8 | douglas
# Processing Record 3 of Set 8 | marsh harbour
# Processing Record 4 of Set 8 | aguimes
# Processing Record 5 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 6 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 7 of Set 8 | airai
# Processing Record 8 of Set 8 | pemangkat
# Processing Record 9 of Set 8 | newton
# Processing Record 10 of Set 8 | fairbanks
# Processing Record 11 of Set 8 | samarai
# Processing Record 12 of Set 8 | ormond beach
# Processing Record 13 of Set 8 | wuwei
# Processing Record 14 of Set 8 | laguna
# Processing Record 15 of Set 8 | tateyama
# Processing Record 16 of Set 8 | arlit
# Processing Record 17 of Set 8 | dianopolis
# City not found. Skipping...
# Processing Record 18 of Set 8 | saint augustine
# Processing Record 19 of Set 8 | sorland
# Processing Record 20 of Set 8 | sinnamary
# Processing Record 21 of Set 8 | aswan
# Processing Record 22 of Set 8 | colesberg
# Processing Record 23 of Set 8 | sidi ali
# Processing Record 24 of Set 8 | kidal
# Processing Record 25 of Set 8 | tombouctou
# Processing Record 26 of Set 8 | lata
# Processing Record 27 of Set 8 | havre-saint-pierre
# Processing Record 28 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 8 | lasa
# Processing Record 30 of Set 8 | sandwick
# Processing Record 31 of Set 8 | sarkand
# Processing Record 32 of Set 8 | grand gaube
# Processing Record 33 of Set 8 | faanui
# Processing Record 34 of Set 8 | starkville
# Processing Record 35 of Set 8 | srivardhan
# Processing Record 36 of Set 8 | kontagora
# Processing Record 37 of Set 8 | suhut
# Processing Record 38 of Set 8 | laurel
# Processing Record 39 of Set 8 | karpathos
# Processing Record 40 of Set 8 | kusk
# City not found. Skipping...
# Processing Record 41 of Set 8 | boo
# Processing Record 42 of Set 8 | manuk mangkaw
# Processing Record 43 of Set 8 | gat
# Processing Record 44 of Set 8 | geraldton
# Processing Record 45 of Set 8 | superior
# Processing Record 46 of Set 8 | cidreira
# Processing Record 47 of Set 8 | wanning
# Processing Record 48 of Set 8 | gojra
# Processing Record 49 of Set 8 | najran
# Processing Record 50 of Set 8 | miguel auza
# Processing Record 1 of Set 9 | etchoropo
# Processing Record 2 of Set 9 | wielun
# Processing Record 3 of Set 9 | manakara
# Processing Record 4 of Set 9 | lincoln
# Processing Record 5 of Set 9 | axim
# Processing Record 6 of Set 9 | ostrovnoy
# Processing Record 7 of Set 9 | ambilobe
# Processing Record 8 of Set 9 | sao felix do xingu
# Processing Record 9 of Set 9 | egvekinot
# Processing Record 10 of Set 9 | chissamba
# Processing Record 11 of Set 9 | porto novo
# Processing Record 12 of Set 9 | svetlaya
# Processing Record 13 of Set 9 | concepcion
# Processing Record 14 of Set 9 | pucallpa
# Processing Record 15 of Set 9 | katherine
# Processing Record 16 of Set 9 | baruun-urt
# Processing Record 17 of Set 9 | mocuba
# Processing Record 18 of Set 9 | klaksvik
# Processing Record 19 of Set 9 | buzdyak
# Processing Record 20 of Set 9 | sargur
# Processing Record 21 of Set 9 | caceres
# Processing Record 22 of Set 9 | peregu mare
# Processing Record 23 of Set 9 | san jeronimo
# Processing Record 24 of Set 9 | caravelas
# Processing Record 25 of Set 9 | forestville
# Processing Record 26 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 27 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 28 of Set 9 | inhambane
# Processing Record 29 of Set 9 | matamoros
# Processing Record 30 of Set 9 | dingle
# Processing Record 31 of Set 9 | deputatskiy
# Processing Record 32 of Set 9 | trezzano sul naviglio
# Processing Record 33 of Set 9 | codrington
# Processing Record 34 of Set 9 | xining
# Processing Record 35 of Set 9 | port hedland
# Processing Record 36 of Set 9 | soloneshnoye
# Processing Record 37 of Set 9 | salalah
# Processing Record 38 of Set 9 | la palma
# Processing Record 39 of Set 9 | jinchang
# Processing Record 40 of Set 9 | pozo colorado
# Processing Record 41 of Set 9 | xiaoshi
# Processing Record 42 of Set 9 | bisalpur
# Processing Record 43 of Set 9 | caraballeda
# Processing Record 44 of Set 9 | kamenka
# Processing Record 45 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 46 of Set 9 | loandjili
# Processing Record 47 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 48 of Set 9 | bonnyville
# Processing Record 49 of Set 9 | dipkarpaz
# City not found. Skipping...
# Processing Record 50 of Set 9 | kysyl-syr
# Processing Record 1 of Set 10 | cloquet
# Processing Record 2 of Set 10 | shahi
# Processing Record 3 of Set 10 | abu dhabi
# Processing Record 4 of Set 10 | blackpool
# Processing Record 5 of Set 10 | gamba
# Processing Record 6 of Set 10 | aginskoye
# Processing Record 7 of Set 10 | ramsar
# Processing Record 8 of Set 10 | gillette
# Processing Record 9 of Set 10 | oranjemund
# Processing Record 10 of Set 10 | port blair
# Processing Record 11 of Set 10 | doha
# Processing Record 12 of Set 10 | siva
# Processing Record 13 of Set 10 | bloomingdale
# Processing Record 14 of Set 10 | osypenko
# Processing Record 15 of Set 10 | san andres
# Processing Record 16 of Set 10 | mairwa
# Processing Record 17 of Set 10 | phayao
# Processing Record 18 of Set 10 | mersin
# Processing Record 19 of Set 10 | amurzet
# Processing Record 20 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 21 of Set 10 | grimari
# City not found. Skipping...
# Processing Record 22 of Set 10 | zhigansk
# Processing Record 23 of Set 10 | bustamante
# Processing Record 24 of Set 10 | strunino
# Processing Record 25 of Set 10 | itarema
# Processing Record 26 of Set 10 | vila franca do campo
# Processing Record 27 of Set 10 | strezhevoy
# Processing Record 28 of Set 10 | salta
# Processing Record 29 of Set 10 | ayan
# Processing Record 30 of Set 10 | ostersund
# Processing Record 31 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 10 | lubao
# Processing Record 33 of Set 10 | palma
# Processing Record 34 of Set 10 | koutsouras
# Processing Record 35 of Set 10 | gap
# Processing Record 36 of Set 10 | nemuro
# Processing Record 37 of Set 10 | buala
# Processing Record 38 of Set 10 | kerkini
# Processing Record 39 of Set 10 | shaturtorf
# Processing Record 40 of Set 10 | sumenep
# Processing Record 41 of Set 10 | barisal
# Processing Record 42 of Set 10 | soverato
# Processing Record 43 of Set 10 | rotterdam
# Processing Record 44 of Set 10 | awassa
# Processing Record 45 of Set 10 | maltahohe
# Processing Record 46 of Set 10 | skelleftea
# Processing Record 47 of Set 10 | olafsvik
# Processing Record 48 of Set 10 | vao
# Processing Record 49 of Set 10 | kampot
# Processing Record 50 of Set 10 | a
# City not found. Skipping...
# Processing Record 1 of Set 11 | puerto asis
# Processing Record 2 of Set 11 | tahoua
# Processing Record 3 of Set 11 | mamallapuram
# Processing Record 4 of Set 11 | pisco
# Processing Record 5 of Set 11 | bambous virieux
# Processing Record 6 of Set 11 | jujuy
# City not found. Skipping...
# Processing Record 7 of Set 11 | carutapera
# Processing Record 8 of Set 11 | valparaiso
# Processing Record 9 of Set 11 | oranzherei
# Processing Record 10 of Set 11 | iwaki
# Processing Record 11 of Set 11 | poltava
# Processing Record 12 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 13 of Set 11 | taseyevo
# Processing Record 14 of Set 11 | ingham
# Processing Record 15 of Set 11 | ondjiva
# Processing Record 16 of Set 11 | olinda
# Processing Record 17 of Set 11 | tiznit
# Processing Record 18 of Set 11 | thayetmyo
# Processing Record 19 of Set 11 | namatanai
# Processing Record 20 of Set 11 | santa cruz de tenerife
# Processing Record 21 of Set 11 | san pedro
# Processing Record 22 of Set 11 | vestmannaeyjar
# Processing Record 23 of Set 11 | fortuna
# Processing Record 24 of Set 11 | fuyu
# Processing Record 25 of Set 11 | kloulklubed
# Processing Record 26 of Set 11 | vanimo
# Processing Record 27 of Set 11 | neuquen
# Processing Record 28 of Set 11 | antofagasta
# Processing Record 29 of Set 11 | yumen
# Processing Record 30 of Set 11 | casino
# Processing Record 31 of Set 11 | mattru
# Processing Record 32 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 11 | severodvinsk
# Processing Record 34 of Set 11 | toora-khem
# Processing Record 35 of Set 11 | annau
# Processing Record 36 of Set 11 | coahuayana
# Processing Record 37 of Set 11 | san ramon de la nueva oran
# Processing Record 38 of Set 11 | muravlenko
# Processing Record 39 of Set 11 | markova
# Processing Record 40 of Set 11 | pacifica
# Processing Record 41 of Set 11 | uige
# Processing Record 42 of Set 11 | aosta
# Processing Record 43 of Set 11 | vreed en hoop
# City not found. Skipping...
# Processing Record 44 of Set 11 | kayerkan
# Processing Record 45 of Set 11 | antalaha
# Processing Record 46 of Set 11 | isangel
# Processing Record 47 of Set 11 | puerto leguizamo
# Processing Record 48 of Set 11 | ginda
# Processing Record 49 of Set 11 | zhaotong
# Processing Record 50 of Set 11 | ladario
# Processing Record 1 of Set 12 | jacksonville
# Processing Record 2 of Set 12 | shimoda
# Processing Record 3 of Set 12 | valleyview
# Processing Record 4 of Set 12 | den helder
# Processing Record 5 of Set 12 | marawi
# Processing Record 6 of Set 12 | batagay
# Processing Record 7 of Set 12 | ixtapa
# Processing Record 8 of Set 12 | moose factory
# Processing Record 9 of Set 12 | matara
# Processing Record 10 of Set 12 | ust-nera
# Processing Record 11 of Set 12 | kavaratti
# Processing Record 12 of Set 12 | katsina
# Processing Record 13 of Set 12 | alenquer
# Processing Record 14 of Set 12 | northam
# Processing Record 15 of Set 12 | lubango
# Processing Record 16 of Set 12 | sabang
# Processing Record 17 of Set 12 | mackenzie
# Processing Record 18 of Set 12 | trat
# Processing Record 19 of Set 12 | krasnoselkup
# Processing Record 20 of Set 12 | sur
# Processing Record 21 of Set 12 | leeston
# Processing Record 22 of Set 12 | sozimskiy
# Processing Record 23 of Set 12 | broome
# Processing Record 24 of Set 12 | polovinnoye
# Processing Record 25 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 26 of Set 12 | bellefontaine
# Processing Record 27 of Set 12 | anan
# Processing Record 28 of Set 12 | ternate
# Processing Record 29 of Set 12 | ondangwa
# Processing Record 30 of Set 12 | morgan city
# Processing Record 31 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 12 | kyren
# Processing Record 33 of Set 12 | ballina
# Processing Record 34 of Set 12 | emerald
# Processing Record 35 of Set 12 | harper
# Processing Record 36 of Set 12 | uspenskaya
# Processing Record 37 of Set 12 | yaring
# Processing Record 38 of Set 12 | san juan
# Processing Record 39 of Set 12 | jaipur hat
# City not found. Skipping...
# Processing Record 40 of Set 12 | palora
# Processing Record 41 of Set 12 | dodge city
# Processing Record 42 of Set 12 | chiang kham
# Processing Record 43 of Set 12 | saint-pacome
# City not found. Skipping...
# Processing Record 44 of Set 12 | raudeberg
# Processing Record 45 of Set 12 | ho
# City not found. Skipping...
# Processing Record 46 of Set 12 | oxford
# Processing Record 47 of Set 12 | tupik
# Processing Record 48 of Set 12 | rafai
# Processing Record 49 of Set 12 | ancona
# Processing Record 50 of Set 12 | katsuura
# Processing Record 1 of Set 13 | puri
# Processing Record 2 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 13 | taitung
# Processing Record 4 of Set 13 | tezu
# Processing Record 5 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 6 of Set 13 | kostomuksha
# Processing Record 7 of Set 13 | las cruces
# Processing Record 8 of Set 13 | kattivakkam
# Processing Record 9 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 10 of Set 13 | nome
# Processing Record 11 of Set 13 | hailar
# Processing Record 12 of Set 13 | nalut
# Processing Record 13 of Set 13 | iracoubo
# Processing Record 14 of Set 13 | tabuk
# Processing Record 15 of Set 13 | moindou
# Processing Record 16 of Set 13 | rawson
# Processing Record 17 of Set 13 | korla
# Processing Record 18 of Set 13 | songling
# Processing Record 19 of Set 13 | chavakkad
# Processing Record 20 of Set 13 | thongwa
# Processing Record 21 of Set 13 | camacupa
# Processing Record 22 of Set 13 | mao
# Processing Record 23 of Set 13 | chipata
# Processing Record 24 of Set 13 | puerto escondido
# Processing Record 25 of Set 13 | suffolk
# Processing Record 26 of Set 13 | faya
# Processing Record 27 of Set 13 | coetupo
# City not found. Skipping...
# Processing Record 28 of Set 13 | vieques
# Processing Record 29 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 30 of Set 13 | biltine
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Creates dataFrame and reorders columns
city_data_df = pd.DataFrame(city_data)
city_data_new_column_order = ['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed', 'Description', 'Rain Inches (last 3 hrs)', 'Snow Inches (last 3 hrs)']
city_data_df = city_data_df[city_data_new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
